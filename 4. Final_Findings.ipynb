# %% [markdown]
# <div style="background-color:#e2f0d9; padding:15px; border-radius:15px; color:#003366; font-family:Arial; font-size:18px;">
#     <span style="font-size:28px; font-weight:bold;">Final Understandings</span><br>
#
# ### 1. Pricing Insights
# - The average item price is USD 10.37. Most food is cheap, but some items are very costly.
# - Some restaurants keep prices close, others have very big price gaps.
# - A few restaurants (Lucky Moo Foods, The Healthy Hub, IHOP Reynosa) have very high average prices (over USD 140).
# - Fire Ass Thai (USD 1395 item) and buybuy BABY (USD 1099.99 items) sell very expensive items, many are not food.
# - Le Labo sells many costly items, with more than 100 above USD 200.
# - Everyday Needs by Gopuff and Clark Gas Station sell thousands of items under USD 5, making them budget-friendly.
#
# ### 2. Menu & Category Insights
# - Data covers 900,341 unique dishes in 68,876 categories.
# - Fast food and beverages have the most items.
# - The Strollers category is the most expensive, averaging USD 416 per item.
# - Most categories have both cheap and costly items.
# - Over 1.89 million items are priced above the average (USD 10.37).
# - Some stores (like liquor shops) have 2000+ items, while others list only 1.
#
# ### 3. Restaurant Insights
# - There are 60,487 restaurants across 21 states.
# - Ratings go from 1.3 to 5.0, with an average of 4.55.
# - 923 restaurants have a perfect 5.0 rating.
# - Texas has the most restaurants (30,310). Nebraska and Missouri have only 1 each.
# - Texas, Virginia, and Wisconsin have the most top-ranked restaurants.
# - Some states have 1000+ restaurants with good ratings, but small states like Nebraska appear only once.
# - Many states have more than one “best-rated” restaurant with the same top score.
#
# ### 4. Variety & Cuisine Insights
# - Over 500 restaurants serve 10+ cuisines, not just one type of food.
# - Restaurants with 100+ items are mostly liquor or convenience stores, not only food places.
#
# ### 5. Outliers & Performance Gaps
# - Some restaurants do much better or worse than the average in their state.
# - Restaurants with big price gaps target both budget and premium customers.
# - Restaurants with similar prices focus on one type of customer.
# - A few restaurants had $0 menu value, meaning missing or unpriced items.
#
# ### 6. Revenue Potential
# - If each item sold once:
# - Worth The Pour could make the most (USD 69,787.74), followed by Bargain Liquor and Brand Liquors.
# - High revenue comes from big menus or costly items.
# - Small menus or low-cost items bring less revenue but may earn more with volume sales.
#
# ### Uber Eats serves all types of customers:
# - Budget shoppers,
# - Normal everyday food buyers,
# - Premium and luxury buyers.
# - This makes Uber Eats a big, flexible platform for both food and retail delivery.
#
# <span style="font-size:26px; font-weight:bold;">🪄 Final Key Insights</span><br>
# <ul>
#     <li><b>Affordability:</b> Most restaurants offer items under USD 5.</li>
#     <li><b>Luxury Pricing:</b> A few places have items costing USD 200–USD 1,000+.</li>
#     <li><b>High Variety:</b> many menus have over 100 items .</li>
#     <li><b>State Trends:</b> Prices and customer ratings differ across states.</li>
#     <li><b>Quality Rankings:</b> Top-rated restaurants are not always expensive.</li>
#     <li><b>Data Use:</b> This data helps with pricing, marketing, restaurants comperision like cheap/expensive and many more analysis.</li>
# </ul>
# </div>
